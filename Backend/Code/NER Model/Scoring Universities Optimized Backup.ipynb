# %%
import pandas as pd
import numpy as np
import re
import math
import spacy
from tqdm import tqdm, trange
from gensim.models.phrases import Phrases, Phraser
from collections import defaultdict
import multiprocessing
from gensim.models import Word2Vec, KeyedVectors
from time import time
import matplotlib.pyplot as plt
import os
import string
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
import string
from datasets import load_dataset
from multiprocess import Process, cpu_count
import multiprocess as mp
import spacy
from spacy import displacy

# %%
W2V_MODEL_PATH = "../W2V Model/"
NER_MODEL_PATH = "./model-best"

# %%
CUSTOM_OPTIONS = {"colors" : {"SKILL" : "#78C0E0"}}

# %%
w2v_model = Word2Vec.load(W2V_MODEL_PATH + "w2v.model")

# %%
nlp_ner = spacy.load("model-best")
# Out:
# C:\Users\ernes\AppData\Local\Programs\Python\Python310\lib\site-packages\spacy\util.py:877: UserWarning: [W095] Model 'en_pipeline' (0.0.0) was trained with spaCy v3.5 and may not be 100% compatible with the current version (3.5.0). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %% [markdown]
# ### Gathering Module Datasets

# %%
# Getting cached results
skill_sch_code = pd.read_csv('../../Data/skill_sch_code.csv')
modules = pd.read_csv('../../../Data/university_courses/All_courses_info.csv')

# %%
skill_map = {}
for i, row in skill_sch_code.iterrows():
    skill, school, modules = row
    modules = eval(modules)
    if skill not in skill_map:
        skill_map[skill] = {}
    skill_map[skill][school] = modules

# %% [markdown]
# ### Function for preprocessing data

# %%
HTML_PATTERN = re.compile('<.*?>')
STOP_WORDS = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def cleaning(chunk):
    
    # Importing libraries for parallelization later
    import re
    import nltk
    from nltk.corpus import stopwords
    from nltk.stem import WordNetLemmatizer
    HTML_PATTERN = re.compile('<.*?>')
    STOP_WORDS = set(stopwords.words('english'))
    lemmatizer = WordNetLemmatizer()
    
    outputs = []
    for target_input in chunk:
        # convert to lower case
        target_input = target_input.lower()

        # remove websites
        target_input = re.sub(r'http\S+', ' ', target_input)

        # remove html tags
        target_input = re.sub(HTML_PATTERN, ' ', target_input)

        # remove all non-alphabets
        target_input = re.sub("[^A-Za-z']+", ' ', target_input)

        #will remove extra spaces
        target_input = re.sub(r'\s+',' ',target_input)

        # remove stopwords and lemmatize
        target_input_tokens = nltk.word_tokenize(target_input)
        target_input_tokens_wo_stopwords = [lemmatizer.lemmatize(i) for i in target_input_tokens if i not in STOP_WORDS and i]
        
        outputs.append(target_input_tokens_wo_stopwords)
    
    return outputs

# %% [markdown]
# ### Functions for Generating Scores

# %%
def calc_score(cos_sim):
    """
    Calculates a score from 0 to 100 given a cosine-similarity score that ranges from -1 to 1
    
    Details:
    Let A be the angle between two vectors u and v. In other words, cos_sim = cos(A)
    score = A/180 * 100
    """
    
    # To handle computational rounding errors. Sometimes cos_sim is 1.00001 or -1.00001
    if cos_sim > 1: cos_sim = 1
    elif cos_sim < -1: cos_sim = -1
    
    return (math.pi - math.acos(cos_sim)) * 100 / math.pi

# %%
# def get_doc2doc_score(job_desc, mod_desc, verbose = 1):
#     """
#     Computes the similarity score between two documents. 
#     This function is available if the front-end team wants to compare module against module.
#     """
#     job_desc = nlp_ner(job_desc)
#     mod_desc = nlp_ner(mod_desc)
#     scores = []
#     OOV = [] # Stores out of vocabulary words
    
#     for job_ents in job_desc.ents:
#         job_ents = cleaning([job_ents.text])[0]
#         for job_ent in job_ents:
#             if job_ent not in w2v_model.wv: # If job_ent not found in vocabulary
#                 if job_ent not in OOV and job_ent not in STOP_WORDS:
#                     OOV.append(job_ent)
#                     if verbose:
#                         print(f"JOB: {job_ent} not found in vocabulary")
#                 scores.append(0)
#                 continue
#             max_cossim = -1
#             best_mod_ent = None
#             for mod_ents in mod_desc.ents:
#                 mod_ents = cleaning([mod_ents.text])[0]
#                 for mod_ent in mod_ents:
#                     if mod_ent not in w2v_model.wv:
#                         if mod_ent not in STOP_WORDS and mod_ent not in OOV:
#                             OOV.append(mod_ent)
#                             if verbose:
#                                 print(f"MODULE: {mod_ent} not found in vocabulary")
#                     else:
#                         cos_sim = w2v_model.wv.similarity(job_ent, mod_ent)
                        
#                         # To handle computational rounding errors. Sometimes cos_sim is 1.00001 or -1.00001
#                         if cos_sim > 1: cos_sim = 1
#                         elif cos_sim < -1: cos_sim = -1
                            
#                         if cos_sim >= max_cossim:
#                             max_cossim = cos_sim
#                             best_mod_ent = mod_ent
#                 if best_mod_ent == None:
#                     if verbose:
#                         print(f"No matching skills found for {job_ent} in {mod_desc}")
#                     scores.append(0)
#                 else:
#                     score = calc_score(max_cossim)
#                     scores.append(score)

#     return np.mean(np.array(scores))

# %%
def process_job_desc(job_desc):
    job_desc = nlp_ner(job_desc)
    result = [cleaning([job_ents.text])[0] for job_ents in job_desc.ents]
    return result

# %%
def get_skill2mod_score(skill, mod_desc):
    """
    Generates a score and the skill token identified in `mod_desc` with the closest match to `skill`
    """
    mod_desc = nlp_ner(mod_desc)
    max_score = 0
    best_ent = None
    if skill not in w2v_model.wv:
        return max_score, best_ent
    for mod_ents in mod_desc.ents:
        mod_ents = cleaning([mod_ents.text])[0]
        for mod_ent in mod_ents:
            if mod_ent in w2v_model.wv:
                cos_sim = w2v_model.wv.similarity(mod_ent, skill)
                
                # To handle computational rounding errors. Sometimes cos_sim is 1.00001 or -1.00001
                if cos_sim > 1: cos_sim = 1
                elif cos_sim < -1: cos_sim = -1
                    
                score = calc_score(cos_sim)
                if max_score < score:
                    best_ent = mod_ent
                max_score = max(max_score, score)
            else:
                max_score = max(max_score, 0)
    return max_score, best_ent

# %%
def get_school_scores(all_schools):
    """
    Assigns a score to every school. Score ranges from 0 to 100
    """
    all_scores = {}
    num_skills = len(all_schools)
    for skill in all_schools.keys():
        schools = all_schools[skill].keys()
        for school in schools:
            score = all_schools[skill][school][1]
            if school not in all_scores: all_scores[school] = 0
            all_scores[school] += score
    for school, total_score in all_scores.items():
        all_scores[school] = total_score / num_skills
    return all_scores

# %%
def get_mod_recommendations(job_desc):
    """
    WARNING: This function takes about 1-2 minutes to run
    Given a job description (JD), this function will identify all skills within the JD, 
    and recommend a module per school for each identified skill
    
    Input: Job description (str)
    Output: Module recommendations, School scores (dictionary D1 of the format below, dictionary D2 of the format below)
    
    Format of D1:
    {
        JD_skill_1 : {
            school_1 : (school_1_module, score_for_school_1_module),
            school_2 : (school_2_module, score_for_school_2_module),
            school_3 : (school_3_module, score_for_school_3_module),
            ...
        },
        JD_skill_2 : {
            school_1 : (school_1_module, score_for_school_1_module),
            school_2 : (school_2_module, score_for_school_2_module),
            school_3 : (school_3_module, score_for_school_3_module),
            ...
        },
        JD_skill_3 : {
            school_1 : (school_1_module, score_for_school_1_module),
            school_2 : (school_2_module, score_for_school_2_module),
            school_3 : (school_3_module, score_for_school_3_module),
            ...
        },
        ...
    }
    
    Format of D2:
    {
        school_1 : score,
        school_2 : score,
        school_3 : score,
        ...
    }
    """
    
    all_schools = {}
    job_desc = process_job_desc(job_desc)
    for skill_words in job_desc:
        best_mods = {} # {school_1 : (best_mod_1, score_1), school2 : (best_mod_2, score_2), ..., school6 : (best_mod_6, score_6)}
        for jd_skill in skill_words:
            for mod_skill, school_mods in skill_map.items():
                cos_sim = get_cos_sim(mod_skill, jd_skill)
                for school, mods in school_mods.items():
                    if school not in best_mods or best_mods[school][1] < cos_sim:
                        best_mods[school] = (" ".join([str(mod) for mod in mods]), cos_sim)
        all_schools[" ".join(skill_words)] = best_mods
    
    return all_schools, get_school_scores(all_schools)

# %%
def get_cos_sim(word1, word2):
    cos_sim = -1
    if word1 not in w2v_model.wv or word2 not in w2v_model.wv:
        return cos_sim
    else:
        cos_sim = w2v_model.wv.similarity(word1, word2)            
        # To handle computational rounding errors. Sometimes cos_sim is 1.00001 or -1.00001
        if cos_sim > 1: cos_sim = 1
        elif cos_sim < -1: cos_sim = -1
        return cos_sim

# %% [markdown]
# ### Demo

# %%
job_desc = """
What a College Intern - Data Science does at HP:
Attached to the "Smart Manufacturing Application and Research Center".
Work with an enterprising team of data scientists and build solutions to track, analyze and visualize the manufacturing and outbound quality of our supplies.
Generate deep insights through the analysis of data and understanding of operational processes and turn them into actionable recommendations.
Develop methodologies for optimizing our business processes through data visualization, real-time monitoring, predictive analytics etc.
Are you a high-performer? We are looking for an individual with:
Studying Bachelor’s degree in Computer Science, Business Analytics, Information Systems, Industrial Engineering, Statistics with good experience in programming.
Excellent analytical thinking, programming (using R/Python is desirable), and problem-solving skills.
Knowledge of data analytics, data warehousing, database management (preferably using SQL) and data visualization using RShiny and Plotly.
Fundamental knowledge of statistics and probability.
Good visualization skills to create real-time dashboards and/or reports to inform trends and insights.
"""

# %%
mod_desc1 = """
This module covers common algorithmic techniques for solving optimisation problems, and introduces students to approaches for finding good-enough solutions to NP-hard problems. Topics covered include linear and integer programming, network flow algorithms, local search heuristics, approximation algorithms, and randomized algorithms. Through analysis and application of the techniques to a variety of canonical problems, students develop confidence to (i) appropriately model a given optimisation problem, (ii) apply appropriate algorithmic techniques to solve the problem, (iii) analyse the properties of the problem and candidate algorithms, such as time and space complexity, convergence, approximability, and optimality bound.
"""

# %%
mod_desc2 = """
Data visualisation is an essential tool for data analytics. This module is an introduction to data cleaning, exploration, analysis and visualisation. Students will learn how to take raw data, extract meaningful information, use statistical tools, and make visualisations. Topics include: programming in R, introduction to data storage systems, data manipulation, exploratory data analysis, dimension reduction, statistical graphics for univariate, multivariate (high-dimensional), temporal and spatial data, basic design principles and critical evaluation of visual displays of data.
"""

# %%
spacy.displacy.render(nlp_ner(job_desc), style = 'ent', jupyter=True, options = CUSTOM_OPTIONS)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"></br>What a College Intern - Data Science does at HP:</br>Attached to the &quot;Smart Manufacturing Application and Research Center&quot;.</br>Work with an enterprising team of data scientists and build solutions to track,
# <mark class="entity" style="background: #78C0E0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     analyze and visualize the manufacturing
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  and outbound quality of our supplies.</br>Generate deep insights through the
# <mark class="entity" style="background: #78C0E0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     analysis of data
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  and understanding of operational
# <mark class="entity" style="background: #78C0E0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     processes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  and turn them into actionable recommendations.</br>Develop methodologies for optimizing our business processes through
# <mark class="entity" style="background: #78C0E0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     data visualization
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# ,
# <mark class="entity" style="background: #78C0E0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     real-time monitoring
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# ,
# <mark class="entity" style="background: #78C0E0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     predictive analytics
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  etc.</br>Are you a high-performer? We are looking for an individual with:</br>Studying Bachelor’s degree in
# <mark class="entity" style="background: #78C0E0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Computer Science,
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#
# <mark class="entity" style="background: #78C0E0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Business Analytics
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# ,
# <mark class="entity" style="background: #78C0E0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Information Systems
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# ,
# <mark class="entity" style="background: #78C0E0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Industrial Engineering
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# ,
# <mark class="entity" style="background: #78C0E0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Statistics
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  with good experience in
# <mark class="entity" style="background: #78C0E0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     programming
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# .</br>Excellent
# <mark class="entity" style="background: #78C0E0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     analytical thinking
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# ,
# <mark class="entity" style="background: #78C0E0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     programming (using R/Python
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  is desirable), and problem-solving skills.</br>Knowledge of
# <mark class="entity" style="background: #78C0E0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     data analytics
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# ,
# <mark class="entity" style="background: #78C0E0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     data warehousing
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# ,
# <mark class="entity" style="background: #78C0E0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     database management
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  (preferably using
# <mark class="entity" style="background: #78C0E0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SQL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# ) and
# <mark class="entity" style="background: #78C0E0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     data visualization
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  using
# <mark class="entity" style="background: #78C0E0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     RShiny and Plotly
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# .</br>Fundamental knowledge of
# <mark class="entity" style="background: #78C0E0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     statistics
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  and
# <mark class="entity" style="background: #78C0E0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     probability.
# Good visualization
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  skills to
# <mark class="entity" style="background: #78C0E0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     create real-time dashboards and/or reports
#     <span style="font-size: 0.8em; font-weight: bold; line-hei

# %%
spacy.displacy.render(nlp_ner(mod_desc1), style = 'ent', jupyter=True, options = CUSTOM_OPTIONS)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"></br>This module covers common algorithmic techniques for solving
# <mark class="entity" style="background: #78C0E0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     optimisation problems
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# , and introduces students to approaches for finding good-enough solutions to
# <mark class="entity" style="background: #78C0E0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NP-hard problems.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  Topics covered include
# <mark class="entity" style="background: #78C0E0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     linear and integer programming
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# ,
# <mark class="entity" style="background: #78C0E0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     network flow algorithms
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# ,
# <mark class="entity" style="background: #78C0E0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     local search heuristics
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# ,
# <mark class="entity" style="background: #78C0E0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     approximation algorithms
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# , and
# <mark class="entity" style="background: #78C0E0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     randomized algorithms.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  Through analysis and application of the techniques to a variety of canonical problems, students develop confidence to (i) appropriately model a given optimisation problem, (ii) apply appropriate algorithmic techniques to solve the problem, (iii) analyse the properties of the problem and
# <mark class="entity" style="background: #78C0E0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     candidate algorithms
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# , such as
# <mark class="entity" style="background: #78C0E0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     time and space complexity
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# ,
# <mark class="entity" style="background: #78C0E0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     convergence
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# ,
# <mark class="entity" style="background: #78C0E0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     approximability
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# , and
# <mark class="entity" style="background: #78C0E0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     optimality bound
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# .</br></div></span>

# %%
spacy.displacy.render(nlp_ner(mod_desc2), style = 'ent', jupyter=True, options = CUSTOM_OPTIONS)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"></br>
# <mark class="entity" style="background: #78C0E0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Data visualisation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  is an essential tool for data analytics. This module is an introduction to
# <mark class="entity" style="background: #78C0E0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     data cleaning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# ,
# <mark class="entity" style="background: #78C0E0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     exploration
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# ,
# <mark class="entity" style="background: #78C0E0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     analysis and visualisation.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  Students will learn how to take raw data, extract meaningful information, use statistical tools, and make visualisations. Topics include:
# <mark class="entity" style="background: #78C0E0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     programming in R
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# , introduction to
# <mark class="entity" style="background: #78C0E0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     data storage systems
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# ,
# <mark class="entity" style="background: #78C0E0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     data manipulation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# ,
# <mark class="entity" style="background: #78C0E0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     exploratory data analysis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# ,
# <mark class="entity" style="background: #78C0E0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     dimension reduction
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# ,
# <mark class="entity" style="background: #78C0E0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     statistical graphics
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  for univariate, multivariate (high-dimensional), temporal and spatial data, basic
# <mark class="entity" style="background: #78C0E0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     design principles
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  and
# <mark class="entity" style="background: #78C0E0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     critical evaluation of visual displays of data
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# .</br></div></span>

# %%
print(f"Score: {get_skill2mod_score('visualization', mod_desc1)}")
print(f"Score: {get_skill2mod_score('visualization', mod_desc2)}")
# Out:
# Score: (53.63886179258952, 'search')
# Score: (71.64724786243553, 'visualisation')

# %%
start_time = time()
mod_reco, school_scores = get_mod_recommendations(job_desc)
end_time = time()

# %%
print(f"Computation completed in {end_time - start_time} seconds")
# Out:
# Computation completed in 3.2550816535949707 seconds

# %%
mod_reco
# Out:
# {'analyze visualize manufacturing': {'NUS': ('DSA2102', 0.5443885),
#   'NTU': ('CZ2001', 0.7533735),
#   'SMU': ('DSA303', 0.56065524),
#   'SUTD': ('50.004', 1.0),
#   'SUSS': ('MKT365', 0.49844226),
#   'SIT': ('CSC1009 CSC3004', 0.44143876)},
#  'analysis data': {'NUS': ('DSA1101 CS2040 DSA2101 DSA2101 ST3131 ST3131 DSA4211 DSA4211 MA3252 MA4270 MA4270 ST3232 ST4250 ST4250 ST3247 CS3230 CS3230 CS3230 CS4243',
#    1.0),
#   'NTU': ('CZ1007 SC1015 MH3511 MH3511 CZ4032', 1.0),
#   'SMU': ('COR1305 CS421 DSA211 DSA211 DSA212 DSA303 DSA303 DSA306 IS415 IS415 IS424 IS460',
#    1.0),
#   'SUTD': ('50.002 50.038 50.04 50.051', 1.0),
#   'SUSS': ('ANL201 ANL305 ACC353 BUS107 MKT365 MKT371', 1.0),
#   'SIT': ('ICT1008', 1.0)},
#  'process': {'NUS': ('DSA1101 ST2132 ST3131 ST3131 ST3131 ST3131 DSA4211 ST4253 ST4253 ST3248 ST3248 ST4234 ST4234 ST4234 ST4234 CS3210 CS3210 CS3210 CS3223 CS4243 CS4248 CS5340  CS5340  CS5340 ',
#    0.47778365),
#   'NTU': ('CZ1003 CC0001 CC0001 CC0001', 1),
#   'SMU': ('IS424 STAT201', 1),
#   'SUTD': ('50.002 50.003', 1),
#   'SUSS': ('ANL303 ACC353 BUS357', 1),
#   'SIT': ('ICT2101 ICT2101', 1)},
#  'data visualization': {'NUS': ('CS1010 DSA1101 DSA1101 CS2040 CS2040 DSA2101 DSA2101 DSA2101 DSA2101 DSA2101 DSA2101 ST3131 DSA4262 DSA4263 DSA4266 ST3232 ST4253 ST3239 ST3247 ST4231 ST4234 CS3210 CS3223 CS4224 CS4224 CS4225 CS4225 CS4225 CS5340  MA4230',
#    1.0),
#   'NTU': ('CZ1007 SC1015 SC1015 SC1015 SC1015 SC1015 SC1015 CZ2007 CZ2007 CZ2007 MH3511 MH3511 MH3511 CZ4041 CZ4032 CZ4032 CZ4032 CZ4032',
#    1.0),
#   'SMU': ('ACCT420 ACCT420 CS421 DSA211 DSA212 DSA212 DSA212 DSA212 DSA212 DSA212 DSA212 DSA303 DSA303 DSA303 DSA303 DSA303 DSA303 DSA303 DSA303 DSA306 DSA306 DSA306 DSA306 DSA306 DSA306 ECON245 IS105 IS105 IS105 IS112 IS112 IS1702 IS417 IS417 IS417 IS417 IS417 IS417 IS417 IS417 IS417 IS424 IS424 IS424 IS424 IS424 IS424 IS424 IS424 IS424 IS424 IS424 IS460 MKTG228 MKTG228',
#    1.0),
#   'SUTD': ('50.001 50.001 50.003 50.004 50.038 50.038 50.038 50.038 50.038 50.043 50.043 50.043 50.043 50.039 50.039 50.045 50.05 50.051 50.051',
#    1.0),
#   'SUSS': ('ANL201 ANL201 ANL201 ANL201 ANL201 ANL252 ANL303 ANL303 ANL303 ANL303 ANL303 ANL303 ANL305 ANL310 ANL310 ANL488 ACC353 ACC353 ACC353 ANL317 ANL351 ANL351 BME363 BME363 BUS352 BUS352 BUS352 ENG233 ICT330 ICT330 MKT365 MKT365 MKT365 MKT371',
#    1.0),
#   'SIT': ('CSC1006 ICT1008 DCM1112 DCM1112 CSC3004 CSC3005 CSC3005 CSC3005 CSC3005 CSC3005 CSC3005 CSC3005',
#    1.0)},
#  'real time monitoring': {'NUS': ('ST4253 ST4253 CS4234', 1.0),
#   'NTU': ('MH2100', 1.0),
#   'SMU': ('COR1305 IS105 IS112 OPIM326', 0.45124924),
#   'SUTD': ('50.052', 1.0),
#   'SUSS': ('FIN203 ANL317', 1.0),
#   'SIT': ('ICT4005', 0.45124924)},
#  'predictive analytics': {'NUS': ('ST4234', 1.0),
#   'NTU': ('CZ4032', 1.0),
#   'SMU': ('DSA301', 1.0),
#   'SUTD': ('50.001 50.043 50.05', 1.0),
#   'SUSS': ('ANL307 ANL307', 1.0),
#   'SIT': ('CSC1006 CSC3005 Not Stated', 1.0)},
#  'computer science': {'NUS': ('DSA2102 CS4243 CS4243 CS4248', 1.0),
#   'NTU': ('MH1812 MH1812 CZ1007 CZ1007 SC1015 CZ2001 CZ2001 CZ4041', 1.0),
#   'SMU': ('DSA201 IS1702', 1.0),
#   'SUTD': ('50.035 50.035 50.035 50.006 50.012 50.012 50.017 50.017 50.044 50.044 50.05 50.05',
#    1.0),
#   'SUSS': ('ANL355', 1.0),
#   'SIT': ('Not Stated', 1.0)},
#  'business analytics': {'NUS': ('MA4230', 1.0),
#   'NTU': ('CZ4032 CZ4032 CZ4032', 1.0),
#   'SMU': ('ACCT420 IS417 IS417 IS428 IS428 IS428 IS460 MKTG228 MKTG228', 1.0),
#   'SUTD': ('50.001 50.043 50.05', 1.0),
#   'SUSS': ('ANL252 ANL252 ANL303 ANL310 ANL310 ACC353 ACC353 BME363 BUS352 BUS352 MKT365 MKT371',
#    1.0),
#   'SIT': ('CSC1006 CSC3005 Not Stated', 1.0)},
#  'information system': {'NUS': ('ST2132', 1.0),
#   'NTU': ('CZ2007', 1.0),
#   'SMU': ('DSA201', 1.0),
#   'SUTD': ('50.001 40.319 50.045', 1.0),
#   'SUSS': ('ENG233 ENG233 ENG233 ENG233 ENG233 ENG233 ICT233 ICT330 ICT330 ICT330 ICT330 ICT330',
#    1.0),
#   'SIT': ('CSC2003 CSC3004 CSC3004 CSC3004 CSC3005 CSC3005', 1.0)},
#  'industrial engineering': {'NUS': ('DSA2102', 1.0),
#   'NTU': ('MH1812 CZ1007 CZ2001 CZ2006 CZ3005 CZ3005', 1.0),
#   'SMU': ('DSA212 IS1702 MKTG228 STAT201', 0.5437868),
#   'SUTD': ('50.005 50.006', 1.0),
#   'SUSS': ('BUS107', 0.5437868),
#   'SIT': ('ICT2101 ICT2101 CSC2008 CSC3004', 1.0)},
#  'statistic': {'NUS': ('DSA1101 ST2132 ST2132 ST3131 ST3232 ST4253 ST3239 ST4250 ST3247 ST4231 ST4234 CS4225',
#    1.0),
#   'NTU': ('MH2500 MH3500', 1.0),
#   'SMU': ('COR1305 CS421 IS460', 1.0),
#   'SUTD': ('40.319', 0.55148596),
#   'SUSS': ('BUS105 ANL321 ANL321 ANL321', 1.0),
#   'SIT': ('CSC1006', 1.0)},
#  'programming': {'NUS': ('CS1010 DSA1101 DSA2101 DSA2102 MA3236 MA3252 MA3252 CS3210 CS3210 CS3230 CS4231 CS4231 CS4234',
#    1.0),
#   'NTU': ('CZ2002 MH3511', 1.0),
#   'SMU': ('CS421 DSA211 DSA211 DSA211 DSA212 DSA212 DSA306 IS424 IS460 MKTG228',
#    1.0),
#   'SUTD': ('10.014 10.014 10.014 10.014 10.014 50.001 50.001 50.001 50.003 50.003 50.004 50.012 50.017 50.033 50.046 50.051 50.051 50.051 50.052',
#    1.0),
#   'SUSS': ('ANL252 ANL351 ANL355 ANL355 ANL355 BUS107 BUS107 ICT233', 1.0),
#   'SIT': ('CSC3005', 1.0)},
#  'analytical thinking': {'NUS': ('CS3223', 1.0),
#   'NTU': ('MH1805', 1.0),
#   'SMU': ('IS1702', 1.0),
#   'SUTD': ('50.052', 0.4847964),
#   'SUSS': ('BUS105 ACC353 ACC353', 1.0),
#   'SIT': ('CSC3004', 0.59223527)},
#  'programming using r python': {'NUS': ('CS1010 DSA1101 DSA2101 DSA2102 MA3236 MA3252 MA3252 CS3210 CS3210 CS3230 CS4231 CS4231 CS4234',
#    1.0),
#   'NTU': ('CZ2002 MH3511', 1.0),
#   'SMU': ('CS421 DSA211 DSA211 DSA211 DSA212 DSA212 DSA306 IS424 IS460 MKTG228',
#    1.0),
#   'SUTD': ('10.014 10.014 10.014 10.014 10.014 50.001 50.001 50.001 50.003 50.003 50.004 50.012 50.017 50.033 50.046 50.051 50.051 50.051 50.052',
#    1.0),
#   'SUSS': ('ANL252 ANL351 ANL355 ANL355 ANL355 BUS107 BUS107 ICT233', 1.0),
#   'SIT': ('CSC3005', 1.0)},
#  'data analytics': {'NUS': ('CS1010 DSA1101 DSA1101 CS2040 CS2040 DSA2101 DSA2101 DSA2101 DSA2101 DSA2101 DSA2101 ST3131 DSA4262 DSA4263 DSA4266 ST3232 ST4253 ST3239 ST3247 ST4231 ST4234 CS3210 CS3223 CS4224 CS4224 CS4225 CS4225 CS4225 CS5340  MA4230',
#    1.0),
#   'NTU': ('CZ1007 SC1015 SC1015 SC1015 SC1015 SC1015 SC1015 CZ2007 CZ2007 CZ2007 MH3511 MH3511 MH3511 CZ4041 CZ4032 CZ4032 CZ4032 CZ4032',
#    1.0),
#   'SMU': ('ACCT420 ACCT420 CS421 DSA211 DSA212 DSA212 DSA212 DSA212 DSA212 DSA212 DSA212 DSA303 DSA303 DSA303 DSA303 DSA303 DSA303 DSA303 DSA303 DSA306 DSA306 DSA306 DSA306 DSA306 DSA306 ECON245 IS105 IS105 IS105 IS112 IS112 IS1702 IS417 IS417 IS417 IS417 IS417 IS417 IS417 IS417 IS417 IS424 IS424 IS424 IS424 IS424 IS424 IS424 IS424 IS424 IS424 IS424 IS460 MKTG228 MKTG228',
#    1.0),
#   'SUTD': ('50.001 50.001 50.003 50.004 50.038 50.038 50.038 50.038 50.038 50.043 50.043 50.043 50.043 50.039 50.039 50.045 50.05 50.051 50.051',
#    1.0),
#   'SUSS': ('ANL201 ANL201 ANL201 ANL201 ANL201 ANL252 ANL303 ANL303 ANL303 ANL303 ANL303 ANL303 ANL305 ANL310 ANL310 ANL488 ACC353 ACC353 ACC353 ANL317 ANL351 ANL351 BME363 BME363 BUS352 BUS352 BUS352 ENG233 ICT330 ICT330 MKT365 MKT365 MKT365 MKT371',
#    1.0),
#   'SIT': ('CSC1006 ICT1008 DCM1112 DCM1112 CSC3004 CSC3005 CSC3005 CSC3005 CSC3005 CSC3005 CSC3005 CSC3005',
#    1.0)},
#  'data warehousing': {'NUS': ('CS1010 DSA1101 DSA1101 CS2040 CS2040 DSA2101 DSA2101 DSA2101 DSA2101 DSA2101 DSA2101 ST3131 DSA4262 DSA4263 DSA4266 ST3232 ST4253 ST3239 ST3247 ST4231 ST4234 CS3210 CS3223 CS4224 CS4224 CS4225 CS4225 CS4225 CS5340  MA4230',
#    1.0),
#   'NTU': ('CZ1007 SC1015 SC1015 SC1015 SC1015 SC1015 SC1015 CZ2007 CZ2007 CZ2007 MH3511 MH3511 MH3511 CZ4041 CZ4032 CZ4032 CZ4032 CZ4032',
#    1.0),
#   'SMU': ('ACCT420 ACCT420 CS421 DSA211 DSA212 DSA212 DSA212 DSA212 DSA212 DSA212 DSA212 DSA303 DSA303 DSA303 DSA303 DSA303 DSA303 DSA303 DSA303 DSA306 DSA306 DSA306 DSA306 DSA306 DSA306 ECON245 IS105 IS105 IS105 IS112 IS112 IS1702 IS417 IS417 IS417 IS417 IS417 IS417 IS417 IS417 IS417 IS424 IS424 IS424 IS424 IS424 IS424 IS424 IS424 IS424 IS424 IS424 IS460 MKTG228 MKTG228',
#    1.0),
#   'SUTD': ('50.001 50.001 50.003 50.004 50.038 50.038 50.038 50.038 50.038 50.043 50.043 50.043 50.043 50.039 50.039 50.045 50.05 50.051 50.051',
#    1.0),
#   'SUSS': ('ANL201 ANL201 ANL201 ANL201 ANL201 ANL252 ANL303 ANL303 ANL303 ANL303 ANL303 ANL303 ANL305 ANL310 ANL310 ANL488 ACC353 ACC353 ACC353 ANL317 ANL351 ANL351 BME363 BME363 BUS352 BUS352 BUS352 ENG233 ICT330 ICT330 MKT365 MKT365 MKT365 MKT371',
#    1.0),
#   'SIT': ('CSC1006 ICT1008 DCM1112 DCM1112 CSC3004 CSC3005 CSC3005 CSC3005 CSC3005 CSC3005 CSC3005 CSC3005',
#    1.0)},
#  'database management': {'NUS': ('CS3223 CS3223 CS4224', 1.0),
#   'NTU': ('CZ2007 HW0218', 1.0),
#   'SMU': ('DSA212 DSA212 IS105 IS105 IS105 IS105 IS112 IS112 IS112 IS112 IS424',
#    1.0),
#   'SUTD': ('50.043 50.043 50.043', 1.0),
#   'SUSS': ('ICT233 ICT233 ICT330 ICT330 ICT330 ICT330 ICT330 ICT330 ICT330 ICT330 ICT330',
#    1.0),
#   'SIT': ('CSC2008 CSC2008', 1.0)},
#  'sql': {'NUS': ('DSA4212', 0.433573),
#   'NTU': ('CZ2007', 0.99999994),
#   'SMU': ('DSA212', 0.99999994),
#   'SUTD': ('50.043', 0.4862296),
#   'SUSS': ('ICT330 ICT330 ICT330', 0.99999994),
#   'SIT': ('CSC3005', 0.4984498)},
#  'rshiny plotly': {'NUS': ('CS1010 CS1010 MA2104 CS3244 CS3244 DSA4212 MA4270',
#    -1),
#   'NTU': ('CZ1003 CC0002', -1),
#   'SMU': ('CS421', -1),
#   'SUTD': ('50.035 50.05', -1),
#   'SUSS': ('ANL321', -1),
#   'SIT': ('CSC3009 ICT1008 CSC3004 CSC3004', -1)},
#  'probability good visualization': {'NUS': ('DSA1101 ST2131 ST2131 ST2131 ST2131',
#    1.0),
#   'NTU': ('MH2500 MH2500', 1.0),
#   'SMU': ('CS421 IS460 STAT201 STAT201 STAT201', 1.0),
#   'SUTD': ('40.319', 0.44138628),
#   'SUSS': ('BUS105 ANL321', 1.0),
#   'SIT': ('CSC3009 ICT1004 ICT1004 CSC1009 CSC2003 CSC2003 CSC3004',
#    0.37559006)},
#  'create real time dashboard report': {'NUS': ('ST4253 ST4253 CS4234', 1.0),
#   'NTU': ('MH2100', 1.0),
#   'SMU': ('IS417', 0.43048415),
#   'SUTD': ('50.051', 1.0),
#   'SUSS': ('ANL201 ICT233', 1.0),
#   'SIT': ('PHE2019', 1.0)}}

# %%
school_scores
# Out:
# {'NUS': 0.8312259586084456,
#  'NTU': 0.8930177830514454,
#  'SMU': 0.8088654946713221,
#  'SUTD': 0.8078046781676156,
#  'SUSS': 0.859153763169334,
#  'SIT': 0.7789982443764096}

# %%
get_mod_recommendations("We require applicants with knowledge in deep learning and computer vision")
# Out:
# ({'deep learning': {'NUS': ('CS4248', 1.0),
#    'NTU': ('SC1015', 1.0),
#    'SMU': ('ACCT420 CS421 IS460', 1.0),
#    'SUTD': ('40.319 50.035 50.035 50.039 50.039 50.039 50.04 50.045', 1.0),
#    'SUSS': ('ANL305', 1.0),
#    'SIT': ('Not Stated', 1.0)},
#   'computer vision': {'NUS': ('DSA2102 CS4243 CS4243 CS4248', 1.0),
#    'NTU': ('MH1812 MH1812 CZ1007 CZ1007 SC1015 CZ2001 CZ2001 CZ4041', 1.0),
#    'SMU': ('DSA201 IS1702', 1.0),
#    'SUTD': ('50.035 50.035 50.035 50.006 50.012 50.012 50.017 50.017 50.044 50.044 50.05 50.05',
#     1.0),
#    'SUSS': ('ANL355', 1.0),
#    'SIT': ('Not Stated', 1.0)}},
#  {'NUS': 1.0, 'NTU': 1.0, 'SMU': 1.0, 'SUTD': 1.0, 'SUSS': 1.0, 'SIT': 1.0})
